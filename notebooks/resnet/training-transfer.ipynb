# %%
# !git clone https://github.com/UN-GCPDS/BananaRipenessCREDA.git
# %cd BananaRipenessCREDA
# !pip install -e . -q
# Out:
# Cloning into 'BananaRipenessCREDA'...
# remote: Enumerating objects: 646, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 646 (delta 127), reused 189 (delta 85), pack-reused 402 (from 1)
# Receiving objects: 100% (646/646), 8.40 MiB | 28.58 MiB/s, done.
# Resolving deltas: 100% (339/339), done.
# /kaggle/working/BananaRipenessCREDA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for banana_creda (pyproject.toml) ... done

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/transfer_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_1.yaml
# Out:
# 2026-04-01 01:58:18.312681: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775008698.337721     218 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775008698.345563     218 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775008698.366233     218 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
