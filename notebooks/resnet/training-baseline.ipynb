# %%
# !git clone https://github.com/UN-GCPDS/BananaRipenessCREDA.git
# %cd BananaRipenessCREDA
# !pip install -e . -q
# Out:
# Cloning into 'BananaRipenessCREDA'...
# remote: Enumerating objects: 632, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 632 (delta 118), reused 180 (delta 81), pack-reused 402 (from 1)
# Receiving objects: 100% (632/632), 8.40 MiB | 28.67 MiB/s, done.
# Resolving deltas: 100% (330/330), done.
# /kaggle/working/BananaRipenessCREDA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for banana_creda (pyproject.toml) ... done

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/base_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_0.yaml
# Out:
# 2026-04-01 01:43:20.452783: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775007800.684337     134 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775007800.748330     134 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775007801.271535     134 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
