# %%
# !git clone https://github.com/UN-GCPDS/BananaRipenessCREDA.git
# %cd BananaRipenessCREDA
# !pip install -e . -q
# Out:
# Cloning into 'BananaRipenessCREDA'...
# remote: Enumerating objects: 669, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 669 (delta 140), reused 209 (delta 95), pack-reused 402 (from 1)
# Receiving objects: 100% (669/669), 8.41 MiB | 28.15 MiB/s, done.
# Resolving deltas: 100% (352/352), done.
# /kaggle/working/BananaRipenessCREDA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for banana_creda (pyproject.toml) ... done

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/da_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_2.yaml
# Out:
# 2026-04-01 03:44:46.293126: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775015086.318015     261 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775015086.325749     261 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775015086.345606     261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/da_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_3.yaml
# Out:
# 2026-04-01 03:55:08.020921: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775015708.044711     376 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775015708.052534     376 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775015708.072774     376 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/da_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_4.yaml
# Out:
# 2026-04-01 04:10:12.990897: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775016613.015613     491 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775016613.023239     491 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775016613.043525     491 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
