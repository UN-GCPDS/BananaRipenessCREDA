# %%
# !git clone https://github.com/UN-GCPDS/BananaRipenessCREDA.git
# %cd BananaRipenessCREDA
# !pip install -e . -q
# Out:
# Cloning into 'BananaRipenessCREDA'...
# remote: Enumerating objects: 669, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 669 (delta 140), reused 209 (delta 95), pack-reused 402 (from 1)
# Receiving objects: 100% (669/669), 8.41 MiB | 28.15 MiB/s, done.
# Resolving deltas: 100% (352/352), done.
# /kaggle/working/BananaRipenessCREDA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for banana_creda (pyproject.toml) ... done

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/transfer_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_1.yaml
# Out:
# 2026-04-01 03:37:49.725549: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775014669.750212     147 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775014669.757997     147 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775014669.778426     147 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775014669.778477     147 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775014669.778485     147 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775014669.778490     147 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Seeds fixed at: 42
#
#  Starting BASELINE experiment (Synthetic Data) on cuda...
#
# Epoch 1/20
# ----------------------------------------
# [Train] Time: 00:13 | Loss: 0.4331 | Acc: 0.8227
#
# [Val] Overall Acc: 0.9724
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9970
#     Class B         | 1.0000
#     Class C         | 0.9343
#     Class D         | 0.9582
# New best model found! (Val Acc: 0.9724)
#
# Epoch 2/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0813 | Acc: 0.9755
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
# New best model found! (Val Acc: 1.0000)
#
# Epoch 3/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0638 | Acc: 0.9820
#
# [Val] Overall Acc: 0.9993
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 0.9970
#     Class D         | 1.0000
#
# Epoch 4/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0430 | Acc: 0.9875
#
# [Val] Overall Acc: 0.9970
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 0.9881
#     Class D         | 1.0000
#
# Epoch 5/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0303 | Acc: 0.9890
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 6/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0132 | Acc: 0.9965
#
# [Val] Overall Acc: 0.9993
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 0.9970
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 7/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0117 | Acc: 0.9962
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 8/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0201 | Acc: 0.9938
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 9/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0187 | Acc: 0.9950
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 10/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0055 | Acc: 0.9985
#
# [Val] Overall Acc: 0.9985
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 0.9940
#     Class D         | 1.0000
#
# Epoch 11/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0034 | Acc: 0.9988
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 12/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0073 | Acc: 0.9972
#
# [Val] Overall Acc: 0.9993
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 0.9970
#
# Epoch 13/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0016 | Acc: 0.9998
#
# [Val] Overall Acc: 0.9955
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 0.9821
#     Class D         | 1.0000
#
# Epoch 14/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0211 | Acc: 0.9940
#
# [Val] Overall Acc: 0.9373
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9910
#     Class B         | 0.9970
#     Class C         | 0.7731
#     Class D         | 0.9881
#
# Epoch 15/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0279 | Acc: 0.9948
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 16/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0230 | Acc: 0.9915
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 17/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0024 | Acc: 1.0000
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 18/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0014 | Acc: 1.0000
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 19/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0049 | Acc: 0.9982
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# Epoch 20/20
# ----------------------------------------
# [Train] Time: 00:10 | Loss: 0.0019 | Acc: 0.9992
#
# [Val] Overall Acc: 1.0000
#   > Class           | Acc
#   ---------------------------
#     Class A         | 1.0000
#     Class B         | 1.0000
#     Class C         | 1.0000
#     Class D         | 1.0000
#
# =============== TRAINING COMPLETE ================
# Total Duration: 04:20
# Best Accuracy: 1.0000
# ==================================================
#
#  Starting TRANSFER experiment (Real Data) on cuda...
#
# Epoch 1/20
# ----------------------------------------
# [Train] Time: 00:02 | Loss: 1.5513 | Acc: 0.6582
#
# [Val] Overall Acc: 0.6853
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.6429
#     Class C         | 0.5446
#     Class D         | 0.6607
# New best model found! (Val Acc: 0.6853)
#
# Epoch 2/20
# ----------------------------------------
# [Train] Time: 00:02 | Loss: 1.3835 | Acc: 0.6582
#
# [Val] Overall Acc: 0.6875
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8571
#     Class B         | 0.6518
#     Class C         | 0.5625
#     Class D         | 0.6786
# New best model found! (Val Acc: 0.6875)
#
# Epoch 3/20
# ----------------------------------------
# [Train] Time: 00:02 | Loss: 1.2649 | Acc: 0.6552
#
# [Val] Overall Acc: 0.6808
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8839
#     Class B         | 0.6339
#     Class C         | 0.5446
#     Class D         | 0.6607
#
# Epoch 4/20
# ----------------------------------------
# [Train] Time: 00:02 | Loss: 1.2195 | Acc: 0.6425
#
# [Val] Overall Acc: 0.6875
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.6429
#     Class C         | 0.5625
#     Class D         | 0.6518
#
# Epoch 5/20
# ----------------------------------------
# [Train] Time: 00:02 | Loss: 1.1126 | Acc: 0.6358
#
# [Val] Overall Acc: 0.6920
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8750
#     Class B         | 0.6518
#     Class C         | 0.5714
#     Class D         | 0.6696
# New best model found! (Val Acc: 0.6920)
#
# Epoch 6/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.9964 | Acc: 0.6478
#
# [Val] Overall Acc: 0.6964
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8839
#     Class B         | 0.6518
#     Class C         | 0.5804
#     Class D         | 0.6696
# New best model found! (Val Acc: 0.6964)
#
# Epoch 7/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.9102 | Acc: 0.6664
#
# [Val] Overall Acc: 0.6897
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.6339
#     Class C         | 0.5179
#     Class D         | 0.7054
#
# Epoch 8/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.8494 | Acc: 0.6612
#
# [Val] Overall Acc: 0.7009
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.6339
#     Class C         | 0.5982
#     Class D         | 0.6786
# New best model found! (Val Acc: 0.7009)
#
# Epoch 9/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.8364 | Acc: 0.6694
#
# [Val] Overall Acc: 0.6987
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.6607
#     Class C         | 0.5000
#     Class D         | 0.7411
#
# Epoch 10/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.8013 | Acc: 0.6731
#
# [Val] Overall Acc: 0.7232
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.6786
#     Class C         | 0.5982
#     Class D         | 0.7232
# New best model found! (Val Acc: 0.7232)
#
# Epoch 11/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.7662 | Acc: 0.6903
#
# [Val] Overall Acc: 0.7210
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.6964
#     Class C         | 0.4911
#     Class D         | 0.8036
#
# Epoch 12/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.6987 | Acc: 0.7119
#
# [Val] Overall Acc: 0.7344
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8839
#     Class B         | 0.7054
#     Class C         | 0.5536
#     Class D         | 0.7946
# New best model found! (Val Acc: 0.7344)
#
# Epoch 13/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.6889 | Acc: 0.7052
#
# [Val] Overall Acc: 0.7455
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8839
#     Class B         | 0.7232
#     Class C         | 0.5893
#     Class D         | 0.7857
# New best model found! (Val Acc: 0.7455)
#
# Epoch 14/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.6606 | Acc: 0.7246
#
# [Val] Overall Acc: 0.7589
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8839
#     Class B         | 0.7143
#     Class C         | 0.5893
#     Class D         | 0.8482
# New best model found! (Val Acc: 0.7589)
#
# Epoch 15/20
# ----------------------------------------
# [Train] Time: 00:05 | Loss: 0.6482 | Acc: 0.7381
#
# [Val] Overall Acc: 0.7589
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8661
#     Class B         | 0.7054
#     Class C         | 0.5804
#     Class D         | 0.8839
#
# Epoch 16/20
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.6357 | Acc: 0.7493
#
# [Val] Overall Acc: 0.7991
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.7679
#     Class C         | 0.6786
#     Class D         | 0.8304
# New best model found! (Val Acc: 0.7991)
#
# Epoch 17/20
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.5665 | Acc: 0.7537
#
# [Val] Overall Acc: 0.7991
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.7321
#     Class C         | 0.6786
#     Class D         | 0.8929
#
# Epoch 18/20
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.5520 | Acc: 0.7657
#
# [Val] Overall Acc: 0.8192
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8839
#     Class B         | 0.7857
#     Class C         | 0.6964
#     Class D         | 0.9107
# New best model found! (Val Acc: 0.8192)
#
# Epoch 19/20
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.5210 | Acc: 0.7784
#
# [Val] Overall Acc: 0.8214
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9107
#     Class B         | 0.6964
#     Class C         | 0.7500
#     Class D         | 0.9286
# New best model found! (Val Acc: 0.8214)
#
# Epoch 20/20
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.5010 | Acc: 0.8007
#
# [Val] Overall Acc: 0.8281
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9107
#     Class B         | 0.7500
#     Class C         | 0.7232
#     Class D         | 0.9286
# New best model found! (Val Acc: 0.8281)
#
# =============== TRAINING COMPLETE ================
# Total Duration: 01:55
# Best Accuracy: 0.8281
# ==================================================
#
#  Generating Final Statistical Reports on Source Test Set...
#
# ======================== REPORT: Source Domain Transfer Test ========================
# Class                | Prec.    | Recall   | F1-Score | Acc.     | Support
# ---------------------------------------------------------------------------
# Class A              | 0.8974   | 0.9375   | 0.9170   | 0.9375   | 112
# Class B              | 0.7544   | 0.7679   | 0.7611   | 0.7679   | 112
# Class C              | 0.8119   | 0.7321   | 0.7700   | 0.7321   | 112
# Class D              | 0.8448   | 0.8750   | 0.8596   | 0.8750   | 112
# ---------------------------------------------------------------------------
# Macro Avg            | 0.8271   | 0.8281   | 0.8269   | 0.8281   | -
# ---------------------------------------------------------------------------
# OVERALL ACCURACY: 0.8281
# ===========================================================================
#
#  Experiment completed. Results saved in: outputs/resnet/experiment_1
