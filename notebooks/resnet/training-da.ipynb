# %%
# !git clone https://github.com/UN-GCPDS/BananaRipenessCREDA.git
# %cd BananaRipenessCREDA
# !pip install -e . -q
# Out:
# Cloning into 'BananaRipenessCREDA'...
# remote: Enumerating objects: 656, done.
# remote: Counting objects: 100% (254/254), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 656 (delta 133), reused 197 (delta 89), pack-reused 402 (from 1)
# Receiving objects: 100% (656/656), 8.41 MiB | 28.31 MiB/s, done.
# Resolving deltas: 100% (345/345), done.
# /kaggle/working/BananaRipenessCREDA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for banana_creda (pyproject.toml) ... done

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/da_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_2.yaml
# Out:
# 2026-04-01 02:11:40.141206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775009500.165858     483 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775009500.173901     483 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775009500.193938     483 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775009500.193967     483 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775009500.193973     483 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775009500.193979     483 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Seeds fixed at: 42
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|███████████████████████████████████████| 83.3M/83.3M [00:00<00:00, 188MB/s]
# Warm-up enabled (Threshold: 0.9)
#  Starting CREDA experiment on cuda...
# Initial Lambda CREDA loss value: 0.0
# Config Lambda CREDA value: 1.0
#
# Epoch 1/20
# ----------------------------------------
# [Train] Time: 00:26 | Loss: 0.3652 | Cls loss: 0.3652 | CREDA loss: -0.1791
#
# [Src Val] Overall Acc: 0.8750
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.8036
#     Class C         | 0.8036
#     Class D         | 0.9464
#
# [Tgt Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9688
#     Class B         | 0.7545
#     Class C         | 0.8482
#     Class D         | 0.9643
#
# Epoch 2/20
# ----------------------------------------
# [Train] Time: 00:25 | Loss: 0.1742 | Cls loss: 0.1742 | CREDA loss: 0.0094
#
# [Src Val] Overall Acc: 0.8951
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.7768
#     Class C         | 0.9196
#     Class D         | 0.9375
#
# [Tgt Val] Overall Acc: 0.8917
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7634
#     Class C         | 0.9241
#     Class D         | 0.9420
#
# Epoch 3/20
# ----------------------------------------
# [Train] Time: 00:25 | Loss: 0.1355 | Cls loss: 0.1355 | CREDA loss: 0.0495
#
# [Src Val] Overall Acc: 0.9018
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9732
#     Class B         | 0.8393
#     Class C         | 0.8393
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.8973
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9509
#     Class B         | 0.8438
#     Class C         | 0.8482
#     Class D         | 0.9464
#
# Epoch 4/20
# ----------------------------------------
# [Train] Time: 00:26 | Loss: 0.1292 | Cls loss: 0.1292 | CREDA loss: 0.0444
#
# [Src Val] Overall Acc: 0.8862
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.8036
#     Class C         | 0.8839
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.9007
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.8214
#     Class C         | 0.8929
#     Class D         | 0.9420
#
#  Warm-up completed at epoch 4: Domain Alignment Activated.
# New CREDA lambda = 0.0588
#
# Epoch 5/20
# ----------------------------------------
# [Train] Time: 00:28 | Loss: 0.1256 | Cls loss: 0.1217 | CREDA loss: 0.0662
#
# [Src Val] Overall Acc: 0.8683
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.7857
#     Class C         | 0.7946
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8783
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9330
#     Class B         | 0.7857
#     Class C         | 0.8214
#     Class D         | 0.9732
# New best model found! (Target Val Acc: 0.8783)
# New CREDA lambda = 0.1171
#
# Epoch 6/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0835 | Cls loss: 0.0762 | CREDA loss: 0.0627
#
# [Src Val] Overall Acc: 0.8683
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.7679
#     Class C         | 0.7679
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8705
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.7500
#     Class C         | 0.7812
#     Class D         | 0.9866
# New CREDA lambda = 0.1747
#
# Epoch 7/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0747 | Cls loss: 0.0638 | CREDA loss: 0.0626
#
# [Src Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.8125
#     Class C         | 0.8214
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.8895
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9598
#     Class B         | 0.8125
#     Class C         | 0.8348
#     Class D         | 0.9509
# New best model found! (Target Val Acc: 0.8895)
# New CREDA lambda = 0.2310
#
# Epoch 8/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0641 | Cls loss: 0.0469 | CREDA loss: 0.0744
#
# [Src Val] Overall Acc: 0.8772
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.8125
#     Class C         | 0.8393
#     Class D         | 0.9643
#
# [Tgt Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.8125
#     Class C         | 0.8259
#     Class D         | 0.9688
# New CREDA lambda = 0.2859
#
# Epoch 9/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0705 | Cls loss: 0.0530 | CREDA loss: 0.0612
#
# [Src Val] Overall Acc: 0.8705
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.7589
#     Class C         | 0.8393
#     Class D         | 0.9821
#
# [Tgt Val] Overall Acc: 0.8705
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9152
#     Class B         | 0.7634
#     Class C         | 0.8348
#     Class D         | 0.9688
# New CREDA lambda = 0.3390
#
# Epoch 10/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0764 | Cls loss: 0.0611 | CREDA loss: 0.0454
#
# [Src Val] Overall Acc: 0.8750
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.7679
#     Class C         | 0.8482
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7812
#     Class C         | 0.8571
#     Class D         | 0.9598
# New CREDA lambda = 0.3900
#
# Epoch 11/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0620 | Cls loss: 0.0507 | CREDA loss: 0.0290
#
# [Src Val] Overall Acc: 0.8817
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.8036
#     Class C         | 0.8571
#     Class D         | 0.9643
#
# [Tgt Val] Overall Acc: 0.8739
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9152
#     Class B         | 0.7589
#     Class C         | 0.8616
#     Class D         | 0.9598
# New CREDA lambda = 0.4387
#
# Epoch 12/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0579 | Cls loss: 0.0629 | CREDA loss: -0.0114
#
# [Src Val] Overall Acc: 0.8817
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7679
#     Class C         | 0.8839
#     Class D         | 0.9375
#
# [Tgt Val] Overall Acc: 0.8728
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8973
#     Class B         | 0.7679
#     Class C         | 0.8839
#     Class D         | 0.9420
# New CREDA lambda = 0.4849
#
# Epoch 13/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0342 | Cls loss: 0.1021 | CREDA loss: -0.1399
#
# [Src Val] Overall Acc: 0.8795
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9107
#     Class B         | 0.8571
#     Class C         | 0.7768
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8304
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8348
#     Class B         | 0.7009
#     Class C         | 0.8304
#     Class D         | 0.9554
# New CREDA lambda = 0.5286
#
# Epoch 14/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.1860 | Cls loss: 0.1703 | CREDA loss: -0.6740
#
# [Src Val] Overall Acc: 0.8438
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.7946
#     Class C         | 0.8393
#     Class D         | 0.8125
#
# [Tgt Val] Overall Acc: 0.6775
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.7455
#     Class B         | 0.3705
#     Class C         | 0.7188
#     Class D         | 0.8750
# New CREDA lambda = 0.5697
#
# Epoch 15/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.4917 | Cls loss: 0.1045 | CREDA loss: -1.0466
#
# [Src Val] Overall Acc: 0.8348
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.7589
#     Class C         | 0.8036
#     Class D         | 0.8482
#
# [Tgt Val] Overall Acc: 0.6507
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.6607
#     Class B         | 0.5893
#     Class C         | 0.8259
#     Class D         | 0.5268
# New CREDA lambda = 0.6081
#
# Epoch 16/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.6367 | Cls loss: 0.0927 | CREDA loss: -1.1995
#
# [Src Val] Overall Acc: 0.8594
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.7768
#     Class C         | 0.8304
#     Class D         | 0.8839
#
# [Tgt Val] Overall Acc: 0.5737
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.5580
#     Class B         | 0.4464
#     Class C         | 0.9152
#     Class D         | 0.3750
# New CREDA lambda = 0.6438
#
# Epoch 17/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.7175 | Cls loss: 0.0751 | CREDA loss: -1.2310
#
# [Src Val] Overall Acc: 0.8237
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8571
#     Class B         | 0.7321
#     Class C         | 0.8125
#     Class D         | 0.8929
#
# [Tgt Val] Overall Acc: 0.6540
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8616
#     Class B         | 0.5268
#     Class C         | 0.7679
#     Class D         | 0.4598
# New CREDA lambda = 0.6770
#
# Epoch 18/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.7551 | Cls loss: 0.0865 | CREDA loss: -1.2432
#
# [Src Val] Overall Acc: 0.8192
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9732
#     Class B         | 0.7054
#     Class C         | 0.7321
#     Class D         | 0.8661
#
# [Tgt Val] Overall Acc: 0.8181
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9598
#     Class B         | 0.6920
#     Class C         | 0.7500
#     Class D         | 0.8705
# New CREDA lambda = 0.7076
#
# Epoch 19/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.7979 | Cls loss: 0.0823 | CREDA loss: -1.2440
#
# [Src Val] Overall Acc: 0.8214
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9554
#     Class B         | 0.6071
#     Class C         | 0.8571
#     Class D         | 0.8661
#
# [Tgt Val] Overall Acc: 0.8192
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9777
#     Class B         | 0.5759
#     Class C         | 0.8616
#     Class D         | 0.8616
# New CREDA lambda = 0.7358
#
# Epoch 20/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.8376 | Cls loss: 0.0815 | CREDA loss: -1.2492
#
# [Src Val] Overall Acc: 0.7723
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.5625
#     Class C         | 0.8125
#     Class D         | 0.7857
#
# [Tgt Val] Overall Acc: 0.7612
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9732
#     Class B         | 0.5089
#     Class C         | 0.7679
#     Class D         | 0.7946
# New CREDA lambda = 0.7616
#
# =============== TRAINING COMPLETE ================
# Total Duration: 09:58
# Best Accuracy: 0.8895
# ==================================================
#
#  Generating Final Statistical Reports...
#
# ========================= REPORT: Target Domain FINAL TEST ==========================
# Class                | Prec.    | Recall   | F1-Score | Acc.     | Support
# ---------------------------------------------------------------------------
# Class A              | 0.9060   | 0.9464   | 0.9258   | 0.9464   | 224
# Class B              | 0.8706   | 0.7812   | 0.8235   | 0.7812   | 224
# Class C              | 0.8421   | 0.9286   | 0.8832   | 0.9286   | 224
# Class D              | 0.9626   | 0.9196   | 0.9406   | 0.9196   | 224
# ---------------------------------------------------------------------------
# Macro Avg            | 0.8953   | 0.8940   | 0.8933   | 0.8940   | -
# ---------------------------------------------------------------------------
# OVERALL ACCURACY: 0.8940
# ===========================================================================
#
#  Generating Visualizations...
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP of Domains saved to: outputs/resnet/experiment_2/Target Test - Domain Alignment_umap_alignment.png
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
#
# Pearson Correlation (LIME vs UMAP for Target Domain):
# UMAP-x → r = 0.0019 | p = 9.5549e-01
# UMAP-y → r = -0.0020 | p = 9.5293e-01
# Saved UMAP plot to outputs/resnet/experiment_2/Target Test - Latent Space_umap_samples.png
#
#  Experiment completed. Results saved in: outputs/resnet/experiment_2

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/da_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_3.yaml
# Out:
# 2026-04-01 02:22:51.994871: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775010172.018749     630 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775010172.026207     630 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775010172.045825     630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775010172.045851     630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775010172.045858     630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775010172.045863     630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Seeds fixed at: 42
# Warm-up enabled (Threshold: 0.9)
#  Starting CREDA experiment on cuda...
# Initial Lambda CREDA loss value: 0.0
# Config Lambda CREDA value: 1.0
#
# Epoch 1/20
# ----------------------------------------
# [Train] Time: 00:40 | Loss: 0.2573 | Cls loss: 0.2573 | CREDA loss: -0.1052
#
# [Src Val] Overall Acc: 0.8884
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9554
#     Class B         | 0.8036
#     Class C         | 0.8393
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.8765
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9494
#     Class B         | 0.7381
#     Class C         | 0.8869
#     Class D         | 0.9315
#
# Epoch 2/20
# ----------------------------------------
# [Train] Time: 00:40 | Loss: 0.1374 | Cls loss: 0.1374 | CREDA loss: 0.0236
#
# [Src Val] Overall Acc: 0.8683
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9107
#     Class B         | 0.8036
#     Class C         | 0.7946
#     Class D         | 0.9643
#
# [Tgt Val] Overall Acc: 0.8475
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8601
#     Class B         | 0.7351
#     Class C         | 0.8185
#     Class D         | 0.9762
#
# Epoch 3/20
# ----------------------------------------
# [Train] Time: 00:39 | Loss: 0.1041 | Cls loss: 0.1041 | CREDA loss: 0.0589
#
# [Src Val] Overall Acc: 0.8906
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9732
#     Class B         | 0.8125
#     Class C         | 0.8036
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.9003
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9851
#     Class B         | 0.8333
#     Class C         | 0.8065
#     Class D         | 0.9762
#
#  Warm-up completed at epoch 3: Domain Alignment Activated.
# New CREDA lambda = 0.0555
#
# Epoch 4/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: 0.1017 | Cls loss: 0.0985 | CREDA loss: 0.0589
#
# [Src Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.8125
#     Class C         | 0.8482
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.8884
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9405
#     Class B         | 0.7887
#     Class C         | 0.8810
#     Class D         | 0.9435
# New best model found! (Target Val Acc: 0.8884)
# New CREDA lambda = 0.1107
#
# Epoch 5/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: 0.1018 | Cls loss: 0.0941 | CREDA loss: 0.0697
#
# [Src Val] Overall Acc: 0.8705
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.7857
#     Class C         | 0.8214
#     Class D         | 0.9464
#
# [Tgt Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9524
#     Class B         | 0.8036
#     Class C         | 0.8482
#     Class D         | 0.9315
# New CREDA lambda = 0.1651
#
# Epoch 6/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: 0.0679 | Cls loss: 0.0581 | CREDA loss: 0.0594
#
# [Src Val] Overall Acc: 0.8817
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8036
#     Class C         | 0.8125
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8921
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9613
#     Class B         | 0.8155
#     Class C         | 0.8363
#     Class D         | 0.9554
# New best model found! (Target Val Acc: 0.8921)
# New CREDA lambda = 0.2186
#
# Epoch 7/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: 0.0581 | Cls loss: 0.0468 | CREDA loss: 0.0516
#
# [Src Val] Overall Acc: 0.8795
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.7589
#     Class C         | 0.8304
#     Class D         | 0.9643
#
# [Tgt Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9702
#     Class B         | 0.7530
#     Class C         | 0.8601
#     Class D         | 0.9524
# New CREDA lambda = 0.2708
#
# Epoch 8/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: 0.0512 | Cls loss: 0.0390 | CREDA loss: 0.0449
#
# [Src Val] Overall Acc: 0.8683
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9554
#     Class B         | 0.7500
#     Class C         | 0.8304
#     Class D         | 0.9375
#
# [Tgt Val] Overall Acc: 0.8876
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9613
#     Class B         | 0.8095
#     Class C         | 0.8423
#     Class D         | 0.9375
# New CREDA lambda = 0.3215
#
# Epoch 9/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: 0.0486 | Cls loss: 0.0458 | CREDA loss: 0.0086
#
# [Src Val] Overall Acc: 0.8728
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.7857
#     Class C         | 0.8125
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8661
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8601
#     Class B         | 0.7917
#     Class C         | 0.8571
#     Class D         | 0.9554
# New CREDA lambda = 0.3704
#
# Epoch 10/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: 0.0086 | Cls loss: 0.0733 | CREDA loss: -0.1749
#
# [Src Val] Overall Acc: 0.7991
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.7768
#     Class C         | 0.7321
#     Class D         | 0.7589
#
# [Tgt Val] Overall Acc: 0.5923
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.1964
#     Class B         | 0.5774
#     Class C         | 0.7708
#     Class D         | 0.8244
# New CREDA lambda = 0.4173
#
# Epoch 11/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.2713 | Cls loss: 0.0953 | CREDA loss: -0.8786
#
# [Src Val] Overall Acc: 0.8103
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.7857
#     Class C         | 0.7500
#     Class D         | 0.7589
#
# [Tgt Val] Overall Acc: 0.4918
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.1815
#     Class B         | 0.1637
#     Class C         | 0.8988
#     Class D         | 0.7232
# New CREDA lambda = 0.4621
#
# Epoch 12/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.4207 | Cls loss: 0.0713 | CREDA loss: -1.0647
#
# [Src Val] Overall Acc: 0.8549
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.7768
#     Class C         | 0.8482
#     Class D         | 0.8304
#
# [Tgt Val] Overall Acc: 0.5149
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.0863
#     Class B         | 0.2887
#     Class C         | 0.8929
#     Class D         | 0.7917
# New CREDA lambda = 0.5047
#
# Epoch 13/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.5348 | Cls loss: 0.0711 | CREDA loss: -1.2007
#
# [Src Val] Overall Acc: 0.8415
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7946
#     Class C         | 0.7232
#     Class D         | 0.9107
#
# [Tgt Val] Overall Acc: 0.6406
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8095
#     Class B         | 0.3065
#     Class C         | 0.9226
#     Class D         | 0.5238
# New CREDA lambda = 0.5449
#
# Epoch 14/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.6153 | Cls loss: 0.0616 | CREDA loss: -1.2423
#
# [Src Val] Overall Acc: 0.7746
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.7589
#     Class C         | 0.7500
#     Class D         | 0.6429
#
# [Tgt Val] Overall Acc: 0.5335
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.3333
#     Class B         | 0.2470
#     Class C         | 0.8631
#     Class D         | 0.6905
# New CREDA lambda = 0.5828
#
# Epoch 15/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.7202 | Cls loss: 0.0661 | CREDA loss: -1.3491
#
# [Src Val] Overall Acc: 0.7522
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8304
#     Class B         | 0.7857
#     Class C         | 0.6607
#     Class D         | 0.7321
#
# [Tgt Val] Overall Acc: 0.5074
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.4137
#     Class B         | 0.2946
#     Class C         | 0.8869
#     Class D         | 0.4345
# New CREDA lambda = 0.6183
#
# Epoch 16/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.7701 | Cls loss: 0.0676 | CREDA loss: -1.3549
#
# [Src Val] Overall Acc: 0.7478
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.7857
#     Class B         | 0.6607
#     Class C         | 0.7768
#     Class D         | 0.7679
#
# [Tgt Val] Overall Acc: 0.5811
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.4881
#     Class B         | 0.2946
#     Class C         | 0.8869
#     Class D         | 0.6548
# New CREDA lambda = 0.6514
#
# Epoch 17/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.8494 | Cls loss: 0.0632 | CREDA loss: -1.4008
#
# [Src Val] Overall Acc: 0.8237
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7768
#     Class C         | 0.8036
#     Class D         | 0.7768
#
# [Tgt Val] Overall Acc: 0.7798
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8780
#     Class B         | 0.5417
#     Class C         | 0.9048
#     Class D         | 0.7946
# New CREDA lambda = 0.6823
#
# Epoch 18/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.8935 | Cls loss: 0.0627 | CREDA loss: -1.4016
#
# [Src Val] Overall Acc: 0.8103
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.7232
#     Class C         | 0.8214
#     Class D         | 0.7500
#
# [Tgt Val] Overall Acc: 0.6004
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.4881
#     Class B         | 0.1875
#     Class C         | 0.9077
#     Class D         | 0.8185
# New CREDA lambda = 0.7108
#
# Epoch 19/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.9547 | Cls loss: 0.0589 | CREDA loss: -1.4260
#
# [Src Val] Overall Acc: 0.7701
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.6875
#     Class C         | 0.7500
#     Class D         | 0.6786
#
# [Tgt Val] Overall Acc: 0.4554
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.3304
#     Class B         | 0.1696
#     Class C         | 0.9643
#     Class D         | 0.3571
# New CREDA lambda = 0.7373
#
# Epoch 20/20
# ----------------------------------------
# [Train] Time: 00:41 | Loss: -0.9809 | Cls loss: 0.0599 | CREDA loss: -1.4117
#
# [Src Val] Overall Acc: 0.7433
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8393
#     Class B         | 0.7411
#     Class C         | 0.7589
#     Class D         | 0.6339
#
# [Tgt Val] Overall Acc: 0.5551
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.5744
#     Class B         | 0.3393
#     Class C         | 0.6250
#     Class D         | 0.6815
# New CREDA lambda = 0.7616
#
# =============== TRAINING COMPLETE ================
# Total Duration: 14:56
# Best Accuracy: 0.8921
# ==================================================
#
#  Generating Final Statistical Reports...
#
# ========================= REPORT: Target Domain FINAL TEST ==========================
# Class                | Prec.    | Recall   | F1-Score | Acc.     | Support
# ---------------------------------------------------------------------------
# Class A              | 0.9580   | 0.9494   | 0.9537   | 0.9494   | 336
# Class B              | 0.8956   | 0.8423   | 0.8681   | 0.8423   | 336
# Class C              | 0.8560   | 0.9196   | 0.8867   | 0.9196   | 336
# Class D              | 0.9371   | 0.9315   | 0.9343   | 0.9315   | 336
# ---------------------------------------------------------------------------
# Macro Avg            | 0.9117   | 0.9107   | 0.9107   | 0.9107   | -
# ---------------------------------------------------------------------------
# OVERALL ACCURACY: 0.9107
# ===========================================================================
#
#  Generating Visualizations...
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP of Domains saved to: outputs/resnet/experiment_3/Target Test - Domain Alignment_umap_alignment.png
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
#
# Pearson Correlation (LIME vs UMAP for Target Domain):
# UMAP-x → r = -0.0019 | p = 9.4528e-01
# UMAP-y → r = -0.0001 | p = 9.9765e-01
# Saved UMAP plot to outputs/resnet/experiment_3/Target Test - Latent Space_umap_samples.png
#
#  Experiment completed. Results saved in: outputs/resnet/experiment_3

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/da_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_4.yaml
# Out:
# 2026-04-01 02:39:20.820050: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775011160.845263     771 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775011160.853012     771 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775011160.875162     771 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775011160.875191     771 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775011160.875195     771 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775011160.875198     771 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Seeds fixed at: 42
# Warm-up enabled (Threshold: 0.9)
#  Starting CREDA experiment on cuda...
# Initial Lambda CREDA loss value: 0.0
# Config Lambda CREDA value: 1.0
#
# Epoch 1/20
# ----------------------------------------
# [Train] Time: 00:28 | Loss: 0.3652 | Cls loss: 0.3652 | CREDA loss: -0.2064
#
# [Src Val] Overall Acc: 0.8661
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9554
#     Class B         | 0.8125
#     Class C         | 0.7321
#     Class D         | 0.9643
#
# [Tgt Val] Overall Acc: 0.8638
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.6920
#     Class C         | 0.8705
#     Class D         | 0.9554
#
# Epoch 2/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.1742 | Cls loss: 0.1742 | CREDA loss: -0.0118
#
# [Src Val] Overall Acc: 0.8996
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.7768
#     Class C         | 0.9018
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8605
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8839
#     Class B         | 0.6875
#     Class C         | 0.9420
#     Class D         | 0.9286
#
# Epoch 3/20
# ----------------------------------------
# [Train] Time: 00:26 | Loss: 0.1355 | Cls loss: 0.1355 | CREDA loss: 0.0355
#
# [Src Val] Overall Acc: 0.8996
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9732
#     Class B         | 0.8304
#     Class C         | 0.8393
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.8929
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.8438
#     Class C         | 0.8839
#     Class D         | 0.9241
#
# Epoch 4/20
# ----------------------------------------
# [Train] Time: 00:26 | Loss: 0.1292 | Cls loss: 0.1292 | CREDA loss: 0.0333
#
# [Src Val] Overall Acc: 0.8795
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9107
#     Class B         | 0.7946
#     Class C         | 0.8571
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.8795
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.7723
#     Class C         | 0.8973
#     Class D         | 0.9286
#
# Epoch 5/20
# ----------------------------------------
# [Train] Time: 00:26 | Loss: 0.1207 | Cls loss: 0.1207 | CREDA loss: 0.0614
#
# [Src Val] Overall Acc: 0.8772
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9107
#     Class B         | 0.8125
#     Class C         | 0.8125
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8705
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.7768
#     Class C         | 0.8571
#     Class D         | 0.9554
#
# Epoch 6/20
# ----------------------------------------
# [Train] Time: 00:26 | Loss: 0.0740 | Cls loss: 0.0740 | CREDA loss: 0.0711
#
# [Src Val] Overall Acc: 0.8772
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9554
#     Class B         | 0.7946
#     Class C         | 0.7857
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8873
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9554
#     Class B         | 0.7991
#     Class C         | 0.8259
#     Class D         | 0.9688
#
#  Warm-up completed at epoch 6: Domain Alignment Activated.
# New CREDA lambda = 0.0666
#
# Epoch 7/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0681 | Cls loss: 0.0632 | CREDA loss: 0.0737
#
# [Src Val] Overall Acc: 0.8772
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7946
#     Class C         | 0.8393
#     Class D         | 0.9375
#
# [Tgt Val] Overall Acc: 0.8828
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9330
#     Class B         | 0.7946
#     Class C         | 0.8750
#     Class D         | 0.9286
# New best model found! (Target Val Acc: 0.8828)
# New CREDA lambda = 0.1325
#
# Epoch 8/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0586 | Cls loss: 0.0482 | CREDA loss: 0.0788
#
# [Src Val] Overall Acc: 0.8884
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9107
#     Class B         | 0.8214
#     Class C         | 0.8571
#     Class D         | 0.9643
#
# [Tgt Val] Overall Acc: 0.8806
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.7946
#     Class C         | 0.8527
#     Class D         | 0.9464
# New CREDA lambda = 0.1974
#
# Epoch 9/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0653 | Cls loss: 0.0539 | CREDA loss: 0.0578
#
# [Src Val] Overall Acc: 0.8661
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8929
#     Class B         | 0.7589
#     Class C         | 0.8393
#     Class D         | 0.9732
#
# [Tgt Val] Overall Acc: 0.8717
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9330
#     Class B         | 0.7232
#     Class C         | 0.8795
#     Class D         | 0.9509
# New CREDA lambda = 0.2605
#
# Epoch 10/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0588 | Cls loss: 0.0498 | CREDA loss: 0.0347
#
# [Src Val] Overall Acc: 0.8795
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.7857
#     Class C         | 0.8571
#     Class D         | 0.9554
#
# [Tgt Val] Overall Acc: 0.8583
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9241
#     Class B         | 0.7009
#     Class C         | 0.8616
#     Class D         | 0.9464
# New CREDA lambda = 0.3215
#
# Epoch 11/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: 0.0423 | Cls loss: 0.0543 | CREDA loss: -0.0373
#
# [Src Val] Overall Acc: 0.8750
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.8125
#     Class C         | 0.8571
#     Class D         | 0.9286
#
# [Tgt Val] Overall Acc: 0.8382
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8839
#     Class B         | 0.6607
#     Class C         | 0.8616
#     Class D         | 0.9464
# New CREDA lambda = 0.3799
#
# Epoch 12/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.0252 | Cls loss: 0.0892 | CREDA loss: -0.3011
#
# [Src Val] Overall Acc: 0.8728
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.7946
#     Class C         | 0.8214
#     Class D         | 0.9464
#
# [Tgt Val] Overall Acc: 0.6239
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.4866
#     Class B         | 0.3705
#     Class C         | 0.7679
#     Class D         | 0.8705
# New CREDA lambda = 0.4355
#
# Epoch 13/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.2156 | Cls loss: 0.1032 | CREDA loss: -0.7319
#
# [Src Val] Overall Acc: 0.8594
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.7500
#     Class C         | 0.8036
#     Class D         | 0.9196
#
# [Tgt Val] Overall Acc: 0.4185
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.0536
#     Class B         | 0.1741
#     Class C         | 0.5312
#     Class D         | 0.9152
# New CREDA lambda = 0.4879
#
# Epoch 14/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.3981 | Cls loss: 0.0816 | CREDA loss: -0.9832
#
# [Src Val] Overall Acc: 0.7478
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.5714
#     Class C         | 0.6696
#     Class D         | 0.7857
#
# [Tgt Val] Overall Acc: 0.4208
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.0134
#     Class B         | 0.1875
#     Class C         | 0.7812
#     Class D         | 0.7009
# New CREDA lambda = 0.5370
#
# Epoch 15/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.4847 | Cls loss: 0.0846 | CREDA loss: -1.0601
#
# [Src Val] Overall Acc: 0.8371
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.7054
#     Class C         | 0.8393
#     Class D         | 0.8393
#
# [Tgt Val] Overall Acc: 0.5078
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.3170
#     Class B         | 0.1696
#     Class C         | 0.8304
#     Class D         | 0.7143
# New CREDA lambda = 0.5828
#
# Epoch 16/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.5967 | Cls loss: 0.0771 | CREDA loss: -1.1563
#
# [Src Val] Overall Acc: 0.7679
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9732
#     Class B         | 0.6339
#     Class C         | 0.8482
#     Class D         | 0.6161
#
# [Tgt Val] Overall Acc: 0.5904
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.2009
#     Class B         | 0.6964
#     Class C         | 0.8348
#     Class D         | 0.6295
# New CREDA lambda = 0.6251
#
# Epoch 17/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.6561 | Cls loss: 0.0752 | CREDA loss: -1.1698
#
# [Src Val] Overall Acc: 0.7790
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.6339
#     Class C         | 0.7946
#     Class D         | 0.7500
#
# [Tgt Val] Overall Acc: 0.4732
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.2812
#     Class B         | 0.2679
#     Class C         | 0.5536
#     Class D         | 0.7902
# New CREDA lambda = 0.6640
#
# Epoch 18/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.7178 | Cls loss: 0.0735 | CREDA loss: -1.1917
#
# [Src Val] Overall Acc: 0.8147
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.6875
#     Class C         | 0.7679
#     Class D         | 0.8750
#
# [Tgt Val] Overall Acc: 0.5413
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.3304
#     Class B         | 0.3750
#     Class C         | 0.8929
#     Class D         | 0.5670
# New CREDA lambda = 0.6997
#
# Epoch 19/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.7678 | Cls loss: 0.0743 | CREDA loss: -1.2036
#
# [Src Val] Overall Acc: 0.8393
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.8036
#     Class C         | 0.7321
#     Class D         | 0.8750
#
# [Tgt Val] Overall Acc: 0.5971
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.3393
#     Class B         | 0.5625
#     Class C         | 0.8393
#     Class D         | 0.6473
# New CREDA lambda = 0.7321
#
# Epoch 20/20
# ----------------------------------------
# [Train] Time: 00:27 | Loss: -0.8260 | Cls loss: 0.0661 | CREDA loss: -1.2186
#
# [Src Val] Overall Acc: 0.7388
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.5982
#     Class C         | 0.7500
#     Class D         | 0.6429
#
# [Tgt Val] Overall Acc: 0.4565
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.2902
#     Class B         | 0.2946
#     Class C         | 0.4062
#     Class D         | 0.8348
# New CREDA lambda = 0.7616
#
# =============== TRAINING COMPLETE ================
# Total Duration: 10:10
# Best Accuracy: 0.8828
# ==================================================
#
#  Generating Final Statistical Reports...
#
# ========================= REPORT: Target Domain FINAL TEST ==========================
# Class                | Prec.    | Recall   | F1-Score | Acc.     | Support
# ---------------------------------------------------------------------------
# Class A              | 0.9500   | 0.9330   | 0.9414   | 0.9330   | 224
# Class B              | 0.8776   | 0.7679   | 0.8190   | 0.7679   | 224
# Class C              | 0.7895   | 0.9375   | 0.8571   | 0.9375   | 224
# Class D              | 0.9579   | 0.9152   | 0.9361   | 0.9152   | 224
# ---------------------------------------------------------------------------
# Macro Avg            | 0.8937   | 0.8884   | 0.8884   | 0.8884   | -
# ---------------------------------------------------------------------------
# OVERALL ACCURACY: 0.8884
# ===========================================================================
#
#  Generating Visualizations...
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP of Domains saved to: outputs/resnet/experiment_4/Target Test - Domain Alignment_umap_alignment.png
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
#
# Pearson Correlation (LIME vs UMAP for Target Domain):
# UMAP-x → r = -0.0019 | p = 9.5580e-01
# UMAP-y → r = -0.0168 | p = 6.1627e-01
# Saved UMAP plot to outputs/resnet/experiment_4/Target Test - Latent Space_umap_samples.png
#
#  Experiment completed. Results saved in: outputs/resnet/experiment_4
