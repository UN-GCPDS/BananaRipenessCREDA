# %%
# !git clone https://github.com/UN-GCPDS/BananaRipenessCREDA.git
# %cd BananaRipenessCREDA
# !pip install -e . -q
# Out:
# Cloning into 'BananaRipenessCREDA'...
# remote: Enumerating objects: 604, done.
# remote: Counting objects: 100% (202/202), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 604 (delta 105), reused 158 (delta 74), pack-reused 402 (from 1)
# Receiving objects: 100% (604/604), 8.39 MiB | 29.84 MiB/s, done.
# Resolving deltas: 100% (317/317), done.
# /kaggle/working/BananaRipenessCREDA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for banana_creda (pyproject.toml) ... done

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/base_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_0.yaml
# Out:
# 2026-04-01 00:01:48.917993: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775001709.309751     127 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775001709.416080     127 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775001710.328148     127 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775001710.328200     127 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775001710.328204     127 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775001710.328208     127 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Seeds fixed at: 42
#
#  Starting BASELINE experiment on cuda...
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:09 | Loss: 1.0564 | Acc: 0.5604
#
# [Val] Overall Acc: 0.5647
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.3482
#     Class C         | 0.0000
#     Class D         | 0.9911
# New best model found! (Val Acc: 0.5647)
#
# Epoch 2/25
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.6076 | Acc: 0.7522
#
# [Val] Overall Acc: 0.7768
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9732
#     Class B         | 0.6607
#     Class C         | 0.8482
#     Class D         | 0.6250
# New best model found! (Val Acc: 0.7768)
#
# Epoch 3/25
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.4756 | Acc: 0.8097
#
# [Val] Overall Acc: 0.8147
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8661
#     Class B         | 0.8750
#     Class C         | 0.7768
#     Class D         | 0.7411
# New best model found! (Val Acc: 0.8147)
#
# Epoch 4/25
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.4971 | Acc: 0.7970
#
# [Val] Overall Acc: 0.7835
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.7143
#     Class C         | 0.4821
#     Class D         | 0.9911
#
# Epoch 5/25
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 0.3998 | Acc: 0.8358
#
# [Val] Overall Acc: 0.7679
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.8036
#     Class B         | 0.5089
#     Class C         | 0.8393
#     Class D         | 0.9196
#
# Epoch 6/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.3760 | Acc: 0.8373
#
# [Val] Overall Acc: 0.8527
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.8482
#     Class C         | 0.7054
#     Class D         | 0.9107
# New best model found! (Val Acc: 0.8527)
#
# Epoch 7/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.3406 | Acc: 0.8694
#
# [Val] Overall Acc: 0.8348
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8214
#     Class C         | 0.6607
#     Class D         | 0.9196
#
# Epoch 8/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.3671 | Acc: 0.8612
#
# [Val] Overall Acc: 0.8772
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8839
#     Class C         | 0.7500
#     Class D         | 0.9375
# New best model found! (Val Acc: 0.8772)
#
# Epoch 9/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.3114 | Acc: 0.8784
#
# [Val] Overall Acc: 0.8638
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.8661
#     Class C         | 0.7589
#     Class D         | 0.9107
#
# Epoch 10/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.3041 | Acc: 0.8851
#
# [Val] Overall Acc: 0.8326
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8304
#     Class C         | 0.6161
#     Class D         | 0.9464
#
# Epoch 11/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.3667 | Acc: 0.8560
#
# [Val] Overall Acc: 0.8795
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8036
#     Class C         | 0.9286
#     Class D         | 0.8482
# New best model found! (Val Acc: 0.8795)
#
# Epoch 12/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.3243 | Acc: 0.8590
#
# [Val] Overall Acc: 0.8661
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.8661
#     Class C         | 0.8036
#     Class D         | 0.8750
#
# Epoch 13/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.2682 | Acc: 0.8918
#
# [Val] Overall Acc: 0.8884
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.7768
#     Class C         | 0.9821
#     Class D         | 0.8482
# New best model found! (Val Acc: 0.8884)
#
# Epoch 14/25
# ----------------------------------------
# [Train] Time: 00:08 | Loss: 0.2488 | Acc: 0.9000
#
# [Val] Overall Acc: 0.8906
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8661
#     Class C         | 0.8125
#     Class D         | 0.9464
# New best model found! (Val Acc: 0.8906)
#
# Epoch 15/25
# ----------------------------------------
# [Train] Time: 00:08 | Loss: 0.2517 | Acc: 0.8978
#
# [Val] Overall Acc: 0.8996
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8482
#     Class C         | 0.8304
#     Class D         | 0.9821
# New best model found! (Val Acc: 0.8996)
#
# Epoch 16/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.2602 | Acc: 0.8970
#
# [Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.8661
#     Class C         | 0.7857
#     Class D         | 0.9375
#
# Epoch 17/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.2269 | Acc: 0.9015
#
# [Val] Overall Acc: 0.8996
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8393
#     Class C         | 0.8482
#     Class D         | 0.9732
#
# Epoch 18/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.2426 | Acc: 0.9037
#
# [Val] Overall Acc: 0.8951
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7946
#     Class C         | 0.8839
#     Class D         | 0.9643
#
# Epoch 19/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.2363 | Acc: 0.9075
#
# [Val] Overall Acc: 0.8951
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.8482
#     Class C         | 0.8304
#     Class D         | 0.9732
#
# Epoch 20/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.2054 | Acc: 0.9172
#
# [Val] Overall Acc: 0.8862
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8482
#     Class C         | 0.8214
#     Class D         | 0.9375
#
# Epoch 21/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.1736 | Acc: 0.9231
#
# [Val] Overall Acc: 0.8661
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.8839
#     Class C         | 0.7857
#     Class D         | 0.8929
#
# Epoch 22/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.1905 | Acc: 0.9231
#
# [Val] Overall Acc: 0.8884
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8482
#     Class C         | 0.8750
#     Class D         | 0.8929
#
# Epoch 23/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.1653 | Acc: 0.9343
#
# [Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8750
#     Class C         | 0.8304
#     Class D         | 0.8929
#
# Epoch 24/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.1681 | Acc: 0.9284
#
# [Val] Overall Acc: 0.8973
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8571
#     Class C         | 0.8214
#     Class D         | 0.9732
#
# Epoch 25/25
# ----------------------------------------
# [Train] Time: 00:07 | Loss: 0.1648 | Acc: 0.9254
#
# [Val] Overall Acc: 0.8929
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8839
#     Class C         | 0.7857
#     Class D         | 0.9643
#
# =============== TRAINING COMPLETE ================
# Total Duration: 03:35
# Best Accuracy: 0.8996
# ==================================================
#
#  Generating Final Statistical Reports on SOURCE Test Set...
#
# ======================== REPORT: Source Domain BASELINE TEST ========================
# Class                | Prec.    | Recall   | F1-Score | Acc.     | Support
# ---------------------------------------------------------------------------
# Class A              | 0.9160   | 0.9732   | 0.9437   | 0.9732   | 112
# Class B              | 0.8774   | 0.8304   | 0.8532   | 0.8304   | 112
# Class C              | 0.8868   | 0.8393   | 0.8624   | 0.8393   | 112
# Class D              | 0.8974   | 0.9375   | 0.9170   | 0.9375   | 112
# ---------------------------------------------------------------------------
# Macro Avg            | 0.8944   | 0.8951   | 0.8941   | 0.8951   | -
# ---------------------------------------------------------------------------
# OVERALL ACCURACY: 0.8951
# ===========================================================================
#
#  Experiment completed. Results saved in: outputs/resnet/experiment_0
