# %%
# !git clone https://github.com/UN-GCPDS/BananaRipenessCREDA.git
# %cd BananaRipenessCREDA
# !pip install -e . -q
# Out:
# Cloning into 'BananaRipenessCREDA'...
# remote: Enumerating objects: 646, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 646 (delta 127), reused 189 (delta 85), pack-reused 402 (from 1)
# Receiving objects: 100% (646/646), 8.40 MiB | 28.58 MiB/s, done.
# Resolving deltas: 100% (339/339), done.
# /kaggle/working/BananaRipenessCREDA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for banana_creda (pyproject.toml) ... done

# %%
# !python /kaggle/working/BananaRipenessCREDA/scripts/base_train.py \
--config /kaggle/working/BananaRipenessCREDA/configs/training/resnet/experiment_0.yaml
# Out:
# 2026-04-01 01:54:40.362120: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775008480.710461     124 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775008480.819102     124 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775008481.774813     124 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775008481.774870     124 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775008481.774875     124 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775008481.774879     124 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Seeds fixed at: 42
#
#  Starting BASELINE experiment on cuda...
#
# Epoch 1/20
# ----------------------------------------
# [Train] Time: 00:06 | Loss: 1.0638 | Acc: 0.5507
#
# [Val] Overall Acc: 0.5603
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.3839
#     Class C         | 0.0179
#     Class D         | 0.9107
# New best model found! (Val Acc: 0.5603)
#
# Epoch 2/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.6140 | Acc: 0.7612
#
# [Val] Overall Acc: 0.8237
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9643
#     Class B         | 0.7500
#     Class C         | 0.8304
#     Class D         | 0.7500
# New best model found! (Val Acc: 0.8237)
#
# Epoch 3/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.4773 | Acc: 0.8015
#
# [Val] Overall Acc: 0.8013
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8036
#     Class C         | 0.5446
#     Class D         | 0.9196
#
# Epoch 4/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.5040 | Acc: 0.7978
#
# [Val] Overall Acc: 0.8393
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7589
#     Class C         | 0.6786
#     Class D         | 0.9821
# New best model found! (Val Acc: 0.8393)
#
# Epoch 5/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.4029 | Acc: 0.8388
#
# [Val] Overall Acc: 0.8036
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.6250
#     Class C         | 0.7768
#     Class D         | 0.9107
#
# Epoch 6/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.3971 | Acc: 0.8321
#
# [Val] Overall Acc: 0.8795
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.8661
#     Class C         | 0.7857
#     Class D         | 0.9375
# New best model found! (Val Acc: 0.8795)
#
# Epoch 7/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.3445 | Acc: 0.8701
#
# [Val] Overall Acc: 0.8304
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.8036
#     Class C         | 0.6339
#     Class D         | 0.9554
#
# Epoch 8/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.3681 | Acc: 0.8522
#
# [Val] Overall Acc: 0.8750
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.8929
#     Class C         | 0.7857
#     Class D         | 0.9196
#
# Epoch 9/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.3152 | Acc: 0.8739
#
# [Val] Overall Acc: 0.8795
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9107
#     Class B         | 0.7946
#     Class C         | 0.8571
#     Class D         | 0.9554
#
# Epoch 10/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.3070 | Acc: 0.8791
#
# [Val] Overall Acc: 0.8616
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.7946
#     Class C         | 0.7500
#     Class D         | 0.9821
#
# Epoch 11/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.3592 | Acc: 0.8507
#
# [Val] Overall Acc: 0.8906
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8125
#     Class C         | 0.9107
#     Class D         | 0.9018
# New best model found! (Val Acc: 0.8906)
#
# Epoch 12/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.3207 | Acc: 0.8649
#
# [Val] Overall Acc: 0.8839
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.8482
#     Class C         | 0.8839
#     Class D         | 0.8839
#
# Epoch 13/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.2590 | Acc: 0.8925
#
# [Val] Overall Acc: 0.8929
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.7768
#     Class C         | 0.9643
#     Class D         | 0.8929
# New best model found! (Val Acc: 0.8929)
#
# Epoch 14/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.2416 | Acc: 0.9067
#
# [Val] Overall Acc: 0.8906
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9375
#     Class B         | 0.8304
#     Class C         | 0.8393
#     Class D         | 0.9554
#
# Epoch 15/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.2551 | Acc: 0.8925
#
# [Val] Overall Acc: 0.8973
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.8661
#     Class C         | 0.8661
#     Class D         | 0.9286
# New best model found! (Val Acc: 0.8973)
#
# Epoch 16/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.2583 | Acc: 0.9022
#
# [Val] Overall Acc: 0.8817
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9554
#     Class B         | 0.8482
#     Class C         | 0.8125
#     Class D         | 0.9107
#
# Epoch 17/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.2198 | Acc: 0.9082
#
# [Val] Overall Acc: 0.8929
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9464
#     Class B         | 0.8214
#     Class C         | 0.8214
#     Class D         | 0.9821
#
# Epoch 18/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.2295 | Acc: 0.9090
#
# [Val] Overall Acc: 0.8683
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9018
#     Class B         | 0.7768
#     Class C         | 0.8661
#     Class D         | 0.9286
#
# Epoch 19/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.2181 | Acc: 0.9104
#
# [Val] Overall Acc: 0.8683
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9286
#     Class B         | 0.8125
#     Class C         | 0.7946
#     Class D         | 0.9375
#
# Epoch 20/20
# ----------------------------------------
# [Train] Time: 00:03 | Loss: 0.1928 | Acc: 0.9246
#
# [Val] Overall Acc: 0.8884
#   > Class           | Acc
#   ---------------------------
#     Class A         | 0.9196
#     Class B         | 0.8393
#     Class C         | 0.8571
#     Class D         | 0.9375
#
# =============== TRAINING COMPLETE ================
# Total Duration: 01:29
# Best Accuracy: 0.8973
# ==================================================
#
#  Generating Final Statistical Reports on SOURCE Test Set...
#
# ======================== REPORT: Source Domain BASELINE TEST ========================
# Class                | Prec.    | Recall   | F1-Score | Acc.     | Support
# ---------------------------------------------------------------------------
# Class A              | 0.9083   | 0.9732   | 0.9397   | 0.9732   | 112
# Class B              | 0.8857   | 0.8304   | 0.8571   | 0.8304   | 112
# Class C              | 0.8729   | 0.9196   | 0.8957   | 0.9196   | 112
# Class D              | 0.9619   | 0.9018   | 0.9309   | 0.9018   | 112
# ---------------------------------------------------------------------------
# Macro Avg            | 0.9072   | 0.9062   | 0.9058   | 0.9062   | -
# ---------------------------------------------------------------------------
# OVERALL ACCURACY: 0.9062
# ===========================================================================
#
#  Experiment completed. Results saved in: outputs/resnet/experiment_0
